# %% [markdown]
# # Inicializando el dataframe

# %%
import pandas as pd

data = "dataset/Pokemon.csv"

df = pd.read_csv(data)

#Total de registros leídos
len(df)
# Out:
# 800

# %% [markdown]
# ## Mostrando el encabezado del dataframe

# %%
df.head(n = 10) #n = 5 por defecto
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# ## Cambiemos el indice por el nombre del pókemon

# %%
df.set_index("Name", inplace=True) #inplace = True para que no cree una copia del dataframe sino para que modifique el original
df.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# ## Miremos la cantidad de filas y columnas del dataframe

# %%
df.shape #retorna (filas, columnas)
# Out:
# (800, 12)

# %% [markdown]
# ## Tipos de datos por columna en el dataframe

# %%
df.dtypes
# Out:
# #              int64
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ## Visualización nombres de las columnas

# %%
df.columns
# Out:
# Index(['#', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## Convertir valores del dataframe en un numpy array

# %%
df.values
# Out:
# array([[1, 'Grass', 'Poison', ..., 45, 1, False],
#        [2, 'Grass', 'Poison', ..., 60, 1, False],
#        [3, 'Grass', 'Poison', ..., 80, 1, False],
#        ...,
#        [720, 'Psychic', 'Ghost', ..., 70, 6, True],
#        [720, 'Psychic', 'Dark', ..., 80, 6, True],
#        [721, 'Fire', 'Water', ..., 70, 6, True]],
#       shape=(800, 12), dtype=object)

# %% [markdown]
# ## Visualizar la cola del dataframe

# %%
df.tail(n = 8) #por defecto n=5
# Out:
#                        #   Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Xerneas              716    Fairy     NaN    680  126     131       95
# Yveltal              717     Dark  Flying    680  126     131       95
# Zygarde50% Forme     718   Dragon  Ground    600  108     100      121
# Diancie              719     Rock   Fairy    600   50     100      150
# DiancieMega Diancie  719     Rock   Fairy    700   50     160      110
# HoopaHoopa Confined  720  Psychic   Ghost    600   80     110       60
# HoopaHoopa Unbound   720  Psychic    Dark    680   80     160       60
# Volcanion            721     Fire   Water    600   80     110      120
#
#                      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Xerneas                  131       98     99           6       True
# Yveltal                  131       98     99           6       True
# Zygarde50% Forme          81       95     95           6       True
# ...

# %% [markdown]
# ## Visualizar algunos registros de una columna especifica

# %%
df["Generation"].head()
# Out:
# Name
# Bulbasaur                1
# Ivysaur                  1
# Venusaur                 1
# VenusaurMega Venusaur    1
# Charmander               1
# Name: Generation, dtype: int64

# %% [markdown]
# ## Visualizar algunos registros de varias columnas

# %%
df[["HP", "Attack", "Legendary"]].tail(8)
# Out:
#                       HP  Attack  Legendary
# Name
# Xerneas              126     131       True
# Yveltal              126     131       True
# Zygarde50% Forme     108     100       True
# Diancie               50     100       True
# DiancieMega Diancie   50     160       True
# HoopaHoopa Confined   80     110       True
# HoopaHoopa Unbound    80     160       True
# Volcanion             80     110       True
